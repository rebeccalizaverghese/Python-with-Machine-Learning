# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeccalizaverghese/Python-with-Machine-Learning/blob/main/Python_Interactive_Notebook_Class_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CLASS 15**

# %%
#Exploratory Data Analysis (EDA)
 #EDA- explore data| find different insights| analyse data
 #Dataset - https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230522%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230522T122607Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...

# %%
import pandas as pd
df=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230522%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230522T122607Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...", sep='\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
print(df.shape) #Total no. of rows and columns
print(df.size) #total no. of elements in dataframe
# Out:
# (59, 7)
# 413

# %%
#Slicing
 #slice row indexes from 25 to 44
df[25:45] #var[inclusive index (included):exclusive index (excluded/ upto 44)]
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# ...

# %%
#Slice row index from 25 to 44 and columns 0 and 1
df.iloc[25:44,0:2] #var.iloc[row slicing,column slicing]
# Out:
#     fruit_label fruit_name
# 25            3     orange
# 26            3     orange
# 27            3     orange
# 28            3     orange
# 29            3     orange
# 30            3     orange
# 31            3     orange
# 32            3     orange
# 33            3     orange
# 34            3     orange
# 35            3     orange
# 36            3     orange
# 37            3     orange
# 38            3     orange
# 39            3     orange
# 40            3     orange
# 41            3     orange
# 42            3     orange
# 43            4      lemon

# %%
#Exact count of unique fruit names
 #From manual analysis - we know there are 4 unique fruits
print(df['fruit_name'].nunique())
print(df.fruit_name.nunique())
print(df['fruit_name'].unique())
print(df.fruit_name.unique())
# Out:
# 4
# 4
# ['apple' 'mandarin' 'orange' 'lemon']
# ['apple' 'mandarin' 'orange' 'lemon']

# %%
#Count of individual fruits
df.groupby('fruit_name').size()
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %%
df.fruit_name.value_counts()
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
#Supervised Learning - data is well labeled - CLASSIFICATION|REGRESSION
 #Regression - Linear| Decision Tree| Random Forest Regressor
 #Classification - Logistic Regression| Decision Tree| Random Forest| KNN
#Unsupervised Learning - unlabelled data - CLUSTERING
 #K-means|Hierarchial Clustering

# %%
#Steps to build ml model
 # take data and create dataframe
 #preprocessing - filtering dta[EDA]
 #Data Visualisation - graphs etc
 #Divide into input n output
 #Train n test variable
 #Normalize(scaling) the data(inputs)
 #Apply suitable Algorithm - C|C|R
 #Fit the model (maps input with output)
 #predict the output
 #Evaluation:Accuracy score, Confusion Matriz

# %%
#Machine Learning- Supervised Learning - Regression -Linear Regression
 #Types of dataset -Univariate/Single - one column as input and other as output
                 # -Multivariate/Multiple- many columns as input & 1 column as output

# %%
#dataset- area vs prices
#dataset - https://raw.githubusercontent.com/ameenmanna8824/DATASETS/main/areavsprices.csv
  #Area=>sqrt
  #prices=>

# %%
#1.Take data n create dataframe
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/ameenmanna8824/DATASETS/main/areavsprices.csv")
df
# Out:
#    Area   Prices
# 0  1000   550000
# 1  1500   800000
# 2  1800  1050000
# 3  2400  1240000
# 4  3000  1400000
# 5  3500  1650000

# %%
#2.Pre-processing -optional
#3.Data visualization
import matplotlib.pyplot as plt
plt.scatter(df['Area'],df['Prices'], color="green")
plt.title("Area vs Prices")
plt.xlabel("Area")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')
